# %% [markdown]
# Homework 11
# -----
# Sean Lubner

# %%
# %pylab inline
import pymc
import pandas as pd

# load the data
data = pd.read_table('laa_2011_April.txt')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Problem (a)
# ----
# MLE is the average success rate of each player = H / BA = average:

# %%
player_MLEs = pd.DataFrame({'Player': data['Player'], 'MLE': data['AVG']})
player_MLEs.set_index('Player', inplace=True)
player_MLEs
# Out:
#                MLE
# Player
# Aybar, E     0.362
# Izturis, M   0.309
# Kendrick, H  0.308
# Callaspo, A  0.303
# Bourjos, P   0.300
# Conger, H    0.273
# Abreu, B     0.258
# Amarista, A  0.250
# Trumbo, M    0.250
# Hunter, T    0.214
# Wells, V     0.171
# Mathis, J    0.152
# Wilson, B    0.125

# %% [markdown]
# Problem (b)
# -----
#
# For a Beta distribution we know that:
#
# From: http://en.wikipedia.org/wiki/Beta_distribution
#
# E[X]=$\frac{\alpha}{\alpha + \beta}$
# Var[X]=$\frac{\alpha \beta}{(\alpha + \beta)^2 (\alpha +\beta +1)}$
#
# In 2010 the mean batting average was 0.255 and the variance between players was 0.0011.
#
# Using the values above and solving the two above equations for $\alpha$ and $\beta$:
#
# $\alpha =43.78, \beta =127.92$

# %%
# load in the model
import PlayerModel

M = pymc.MCMC(PlayerModel)
N_samp = 10000 # simple model, so can do many samplings
N_burn = N_samp/10
M.sample(N_samp, burn=N_burn, thin=5)
# Out:
#  [                  1%                  ] 131 of 10000 complete in 0.5 sec
#  [-                 2%                  ] 264 of 10000 complete in 1.0 sec
#  [-                 4%                  ] 401 of 10000 complete in 1.5 sec
#  [--                5%                  ] 537 of 10000 complete in 2.0 sec
#  [--                6%                  ] 672 of 10000 complete in 2.5 sec
#  [---               8%                  ] 807 of 10000 complete in 3.0 sec
#  [---               9%                  ] 943 of 10000 complete in 3.5 sec
#  [----             10%                  ] 1075 of 10000 complete in 4.0 sec
#  [----             12%                  ] 1205 of 10000 complete in 4.5 sec
#  [-----            13%                  ] 1336 of 10000 complete in 5.0 sec
#  [-----            14%                  ] 1468 of 10000 complete in 5.5 sec
#  [------           16%                  ] 1600 of 10000 complete in 6.0 sec
#  [------           17%                  ] 1731 of 10000 complete in 6.5 sec
#  [-------          18%                  ] 1862 of 10000 complete in 7.0 sec
#  [-------          19%                  ] 1995 of 10000 complete in 7.5 sec
#  [--------         21%                  ] 2122 of 10000 complete in 8.0 sec
#  [--------         22%                  ] 2250 of 10000 complete in 8.5 sec
#  [---------        23%                  ] 2378 of 10000 complete in 9.0 sec
#  [---------        25%                  ] 2506 of 10000 complete in 9.5 sec
#  [----------       26%                  ] 2634 of 10000 complete in 10.0 sec
#  [----------       27%                  ] 2762 of 10000 complete in 10.5 sec
#  [----------       28%                  ] 2889 of 10000 complete in 11.0 sec
#  [-----------      30%                  ] 3016 of 10000 complete in 11.5 sec
#  [-----------------80%----------        ] 8000 of 10000 complete in 33.1 sec
#  [-----------------81%----------        ] 8114 of 10000 complete in 33.6 sec
#  [-----------------82%-----------       ] 8226 of 10000 complete in 34.1 sec
#  [-----------------83%-----------       ] 8340 of 10000 complete in 34.6 sec
#  [-----------------84%------------      ] 8460 of 10000 complete in 35.1 sec
#  [-----------------85%------------      ] 8565 of 10000 complete in 35.7 sec
#  [-----------------86%------------      ] 8647 of 10000 complete in 36.2 sec
#  [-----------------87%-------------     ] 8733 of 10000 complete in 36.7 sec
#  [-----------------88%-------------     ] 8851 of 10000 complete in 37.2 sec
#  [-----------------89%--------------    ] 8972 of 10000 complete in 37.7 sec
#  [-----------------90%--------------    ] 9087 of 10000 complete in 38.2 sec
#  [-----------------91%--------------    ] 9199 of 10000 complete in 38.7 sec
#  [-----------------93%---------------   ] 9315 of 10000 complete in 39.2 sec
#  [-----------------94%---------------   ] 9434 of 10000 complete in 39.7 sec
#  [-----------------95%----------------  ] 9551 of 10000 complete in 40.2 sec
#  [-----------------96%----------------  ] 9657 of 10000 complete in 40.7 sec
#  [-----------------97%----------------- ] 9775 of 10000 complete in 41.2 sec
#  [-----------------98%----------------- ] 9893 of 10000 complete in 41.7 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 42.1 sec

# %% [markdown]
# Problem (c)
# -----
# Check for convergence (it does converge)

# %%
from pymc import geweke
from pymc.Matplot import geweke_plot
scores = geweke(M)
geweke_plot(scores)

# %%
# PyMC has its own plotting functionality, via the Matplot module
# %pylab inline
from pymc import Matplot

# plot function takes the model (or a single parameter) as an argument:
Matplot.plot(M)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Plotting mu4
# Plotting
#  mu1
# Plotting
#  mu6
# Plotting
#  mu7
# Plotting
#  mu8
# Plotting
#  mu5
# Plotting
#  mu9
# Plotting
#  mu3
# Plotting
#  mu10
# Plotting
#  mu0
# Plotting
#  mu11
# Plotting
#  mu12
# Plotting
#  mu2

# %%
data
# Out:
#     RK       Player Team Pos   G   AB   R   H  2B  3B  HR  RBI  BB  SO  SB  \
# 0    1     Aybar, E  LAA  SS  12   47   3  17   3   0   0    3   0   4   4
# 1    2   Izturis, M  LAA  3B  20   81   8  25   7   0   2    8   6  14   2
# 2    3  Kendrick, H  LAA  2B  26  104  19  32   6   1   6   12  11  22   1
# 3    4  Callaspo, A  LAA  3B  24   89  13  27   3   0   2    8  12  10   0
# 4    5   Bourjos, P  LAA  CF  26   90  10  27   5   4   2    9   5  28   2
# 5    6    Conger, H  LAA   C  14   44   6  12   2   0   2    9   3   9   0
# 6    7     Abreu, B  LAA  RF  25   89  12  23   6   0   1    8  22  21   2
# 7    8  Amarista, A  LAA  2B   3    8   0   2   1   0   0    3   1   3   0
# 8    8    Trumbo, M  LAA  3B  23   84  11  21   5   0   4   13   2  21   2
# 9   10    Hunter, T  LAA  CF  26  103   8  22   2   0   3   11  10  24   1
# 10  11     Wells, V  LAA  CF  25  105  10  18   2   1   1    6   5  21   0
# 11  12    Mathis, J  LAA   C  13   46   3   7   3   0   0    4   1  16   0
# 12  14    Wilson, B  LAA   C   5    8   0   1   0   0   0    0   1   2   0
#
#     CS    AVG    OBP    SLG    OPS
# 0    0  0.362  0.362  0.426  0.787
# 1    2  0.309  0.356  0.469  0.825
# 2    0  0.308  0.385  0.558  0.942
# 3    0  0.303  0.386  0.404  0.791
# 4    4  0.300  0.333  0.511  0.844
# 5    0  0.273  0.333  0.455  0.788
# 6    1  0.258  0.405  0.360  0.765
# 7    0  0.250  0.300  0.375  0.675
# 8    0  0.250  0.276  0.452  0.728
# 9    0  0.214  0.287  0.320  0.607
# 10   1  0.171  0.207  0.238  0.445
# 11   0  0.152  0.167  0.217  0.384
# 12   0  0.125  0.222  0.125  0.347

# %%
data2 = pd.read_table('laa_2011_full.txt')
data2
# Out:
#     RK       Player Team Pos    G   AB   R    H  2B  3B  HR  RBI  BB   SO  SB  \
# 0    5  Callaspo, A  LAA  3B  141  475  54  137  23   0   6   46  58   48   8
# 1    6  Kendrick, H  LAA  2B  140  537  86  153  30   6  18   63  33  119  14
# 2    7     Aybar, E  LAA  SS  143  556  71  155  33   8  10   59  31   68  30
# 3    8   Izturis, M  LAA  3B  122  449  51  124  35   0   5   38  33   65   9
# 4    9   Bourjos, P  LAA  CF  147  502  72  136  26  11  12   43  32  124  22
# 5   10    Hunter, T  LAA  CF  156  580  80  152  24   2  23   82  62  125   5
# 6   11    Trumbo, M  LAA  3B  149  539  65  137  31   1  29   87  25  120   9
# 7   12     Abreu, B  LAA  RF  142  502  54  127  30   1   8   60  78  113  21
# 8   14     Wells, V  LAA  CF  131  505  60  110  15   4  25   66  20   86   9
# 9   15    Conger, H  LAA   C   59  177  14   37   8   0   6   19  17   37   0
# 10  17    Wilson, B  LAA   C   57  111   5   21   8   0   1    8  10   16   0
# 11  19    Mathis, J  LAA   C   93  247  18   43  12   0   3   22  15   75   1
# 12  20  Amarista, A  LAA  2B   23   52   2    8   3   1   0    5   2    8   0
#
#     CS    AVG    OBP    SLG    OPS
# 0    1  0.288  0.366  0.375  0.740
# 1    6  0.285  0.338  0.464  0.802
# 2    6  0.279  0.322  0.421  0.743
# 3    6  0.276  0.334  0.388  0.722
# 4    9  0.271  0.327  0.438  0.765
# 5    7  0.262  0.336  0.429  0.765
# 6    4  0.254  0.291  0.477  0.768
# 7    5  0.253  0.353  0.365  0.717
# 8    4  0.218  0.248  0.412  0.660
# 9    0  0.209  0.282  0.356  0.638
# 10   2  0.189  0.252  0.288  0.540
# 11   2  0.174  0.225  0.259  0.484
# 12   0  0.154  0.182  0.250  0.432
